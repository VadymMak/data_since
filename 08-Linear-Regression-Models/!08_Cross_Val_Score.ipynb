# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = -cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
scores
# Out:
# array([ 9.32552967,  4.9449624 , 11.39665242,  7.0242106 ,  8.38562723])

# %%
scores.mean()
# Out:
# np.float64(8.215396464543606)

# %%
model = Ridge(alpha=1)

# %%
scores = -cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
scores
# Out:
# array([3.15513238, 1.58086982, 5.40455562, 2.21654481, 4.36709384])

# %%
scores.mean()
# Out:
# np.float64(3.344839296530695)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_test_prediction = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_final_test_prediction)
# Out:
# 2.319021579428752

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha=100)

# %%
scores = cross_validate(model, X_train, y_train,
                scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'],
                cv=10)

# %%
scores
# Out:
# {'fit_time': array([0.00174475, 0.00133014, 0.0016799 , 0.00160694, 0.00115776,
#         0.00124264, 0.00136352, 0.00111723, 0.00100183, 0.00094175]),
#  'score_time': array([0.00114608, 0.00151062, 0.00134873, 0.00120974, 0.00121069,
#         0.00126624, 0.00119972, 0.00112867, 0.00096011, 0.00094175]),
#  'test_neg_mean_squared_error': array([ -6.06067062, -10.62703078,  -3.99342608,  -5.00949402,
#          -9.14179955, -13.08625636,  -3.83940454,  -9.05878567,
#          -9.05545685,  -5.77888211]),
#  'test_neg_mean_absolute_error': array([-1.8102116 , -2.54195751, -1.46959386, -1.86276886, -2.52069737,
#         -2.45999491, -1.45197069, -2.37739501, -2.44334397, -1.89979708])}

# %%
scores = pd.DataFrame(scores)
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.001745    0.001146                    -6.060671
# 1  0.001330    0.001511                   -10.627031
# 2  0.001680    0.001349                    -3.993426
# 3  0.001607    0.001210                    -5.009494
# 4  0.001158    0.001211                    -9.141800
# 5  0.001243    0.001266                   -13.086256
# 6  0.001364    0.001200                    -3.839405
# 7  0.001117    0.001129                    -9.058786
# 8  0.001002    0.000960                    -9.055457
# 9  0.000942    0.000942                    -5.778882
#
#    test_neg_mean_absolute_error
# 0                     -1.810212
# 1                     -2.541958
# 2                     -1.469594
# 3                     -1.862769
# 4                     -2.520697
# 5                     -2.459995
# 6                     -1.451971
# 7                     -2.377395
# 8                     -2.443344
# 9                     -1.899797

# %%
scores.mean()
# Out:
# fit_time                        0.001319
# score_time                      0.001192
# test_neg_mean_squared_error    -7.565121
# test_neg_mean_absolute_error   -2.083773
# dtype: float64

# %%
model = Ridge(alpha=1)

# %%
scores = cross_validate(model, X_train, y_train,
                scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'],
                cv=10)

# %%
scores = pd.DataFrame(scores)
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.001726    0.001286                    -2.962508
# 1  0.001283    0.001071                    -3.057378
# 2  0.001294    0.001118                    -2.173740
# 3  0.001308    0.001092                    -0.833034
# 4  0.001268    0.001091                    -3.464018
# 5  0.001229    0.001094                    -8.232647
# 6  0.001472    0.001225                    -1.905864
# 7  0.001334    0.001080                    -2.765048
# 8  0.001279    0.001147                    -4.989505
# 9  0.001570    0.001190                    -2.846438
#
#    test_neg_mean_absolute_error
# 0                     -1.457174
# 1                     -1.555308
# 2                     -1.238770
# 3                     -0.768938
# 4                     -1.434489
# 5                     -1.494316
# 6                     -1.081362
# 7                     -1.250011
# 8                     -1.580971
# 9                     -1.223326

# %%
scores.mean()
# Out:
# fit_time                        0.001376
# score_time                      0.001139
# test_neg_mean_squared_error    -3.323018
# test_neg_mean_absolute_error   -1.308467
# dtype: float64

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_predictions = model.predict(X_test)

# %%
mean_squared_error(y_test, y_predictions)
# Out:
# 2.319021579428752
