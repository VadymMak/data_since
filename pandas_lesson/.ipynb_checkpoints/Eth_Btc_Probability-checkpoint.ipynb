# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt

# %%
start_date = '2020-01-01'
end_date = '2025-05-01'
tickers = ['BTC-USD', 'ETH-USD']

# %%
data = yf.download(tickers, start_date, end_date)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data = data.reset_index()
data.head()
# Out:
# Price        Date        Close                     High              \
# Ticker                 BTC-USD     ETH-USD      BTC-USD     ETH-USD
# 0      2020-01-01  7200.174316  130.802002  7254.330566  132.835358
# 1      2020-01-02  6985.470215  127.410179  7212.155273  130.820038
# 2      2020-01-03  7344.884277  134.171707  7413.715332  134.554016
# 3      2020-01-04  7410.656738  135.069366  7427.385742  136.052719
# 4      2020-01-05  7411.317383  136.276779  7544.497070  139.410202
#
# Price           Low                     Open                   Volume  \
# Ticker      BTC-USD     ETH-USD      BTC-USD     ETH-USD      BTC-USD
# 0       7174.944336  129.198288  7194.892090  129.630661  18565664997
# 1       6935.270020  126.954910  7202.551270  130.820038  20802083465
# 2       6914.996094  126.490021  6984.428711  127.411263  28111481032
# 3       7309.514160  133.040558  7345.375488  134.168518  18444271275
# 4       7400.535645  135.045624  7410.451660  135.072098  19725074095
#
# Price
# Ticker      ETH-USD
# 0        7935230330
# 1        8032709256
# 2       10476845358
# 3        7430904515
# 4        7526675353

# %%
data = data.rename(columns={
    'Date': 'date',
    'BTC-USD': 'btc',
    'ETH-USD': 'eth',
    'Close': 'close',
    'Open': 'open',
    'High': 'high',
    'Low': 'low',
    'Volume': 'volume'
})
data.head()
# Out:
# Price        date        close                     high              \
# Ticker                     btc         eth          btc         eth
# 0      2020-01-01  7200.174316  130.802002  7254.330566  132.835358
# 1      2020-01-02  6985.470215  127.410179  7212.155273  130.820038
# 2      2020-01-03  7344.884277  134.171707  7413.715332  134.554016
# 3      2020-01-04  7410.656738  135.069366  7427.385742  136.052719
# 4      2020-01-05  7411.317383  136.276779  7544.497070  139.410202
#
# Price           low                     open                   volume  \
# Ticker          btc         eth          btc         eth          btc
# 0       7174.944336  129.198288  7194.892090  129.630661  18565664997
# 1       6935.270020  126.954910  7202.551270  130.820038  20802083465
# 2       6914.996094  126.490021  6984.428711  127.411263  28111481032
# 3       7309.514160  133.040558  7345.375488  134.168518  18444271275
# 4       7400.535645  135.045624  7410.451660  135.072098  19725074095
#
# Price
# Ticker          eth
# 0        7935230330
# 1        8032709256
# 2       10476845358
# 3        7430904515
# 4        7526675353

# %%
data.columns = ['_'.join(col).strip() for col in data.columns]
data.head()
# Out:
#        date_    close_btc   close_eth     high_btc    high_eth      low_btc  \
# 0 2020-01-01  7200.174316  130.802002  7254.330566  132.835358  7174.944336
# 1 2020-01-02  6985.470215  127.410179  7212.155273  130.820038  6935.270020
# 2 2020-01-03  7344.884277  134.171707  7413.715332  134.554016  6914.996094
# 3 2020-01-04  7410.656738  135.069366  7427.385742  136.052719  7309.514160
# 4 2020-01-05  7411.317383  136.276779  7544.497070  139.410202  7400.535645
#
#       low_eth     open_btc    open_eth   volume_btc   volume_eth
# 0  129.198288  7194.892090  129.630661  18565664997   7935230330
# 1  126.954910  7202.551270  130.820038  20802083465   8032709256
# 2  126.490021  6984.428711  127.411263  28111481032  10476845358
# 3  133.040558  7345.375488  134.168518  18444271275   7430904515
# 4  135.045624  7410.451660  135.072098  19725074095   7526675353

# %%
data.to_csv('eth_btc_5_year.csv', index=False)
print('Saved to csv file')
# Out:
# Saved to csv file

# %%
df = pd.read_csv('eth_btc_5_year.csv')
df['date_'] = pd.to_datetime(df['date_'])
df.head()
# Out:
#        date_    close_btc   close_eth     high_btc    high_eth      low_btc  \
# 0 2020-01-01  7200.174316  130.802002  7254.330566  132.835358  7174.944336
# 1 2020-01-02  6985.470215  127.410179  7212.155273  130.820038  6935.270020
# 2 2020-01-03  7344.884277  134.171707  7413.715332  134.554016  6914.996094
# 3 2020-01-04  7410.656738  135.069366  7427.385742  136.052719  7309.514160
# 4 2020-01-05  7411.317383  136.276779  7544.497070  139.410202  7400.535645
#
#       low_eth     open_btc    open_eth   volume_btc   volume_eth
# 0  129.198288  7194.892090  129.630661  18565664997   7935230330
# 1  126.954910  7202.551270  130.820038  20802083465   8032709256
# 2  126.490021  6984.428711  127.411263  28111481032  10476845358
# 3  133.040558  7345.375488  134.168518  18444271275   7430904515
# 4  135.045624  7410.451660  135.072098  19725074095   7526675353

# %%
df.loc[1:5, 'close_btc'] = float('nan')
df.loc[2:4, 'volume_eth'] = 0
df.head(6)
# Out:
#        date_    close_btc   close_eth     high_btc    high_eth      low_btc  \
# 0 2020-01-01  7200.174316  130.802002  7254.330566  132.835358  7174.944336
# 1 2020-01-02          NaN  127.410179  7212.155273  130.820038  6935.270020
# 2 2020-01-03          NaN  134.171707  7413.715332  134.554016  6914.996094
# 3 2020-01-04          NaN  135.069366  7427.385742  136.052719  7309.514160
# 4 2020-01-05          NaN  136.276779  7544.497070  139.410202  7400.535645
# 5 2020-01-06          NaN  144.304153  7781.867188  144.328186  7409.292969
#
#       low_eth     open_btc    open_eth   volume_btc  volume_eth
# 0  129.198288  7194.892090  129.630661  18565664997  7935230330
# 1  126.954910  7202.551270  130.820038  20802083465  8032709256
# 2  126.490021  6984.428711  127.411263  28111481032           0
# 3  133.040558  7345.375488  134.168518  18444271275           0
# 4  135.045624  7410.451660  135.072098  19725074095           0
# 5  136.079636  7410.452148  136.305542  23276261598  9093747121

# %%
df.isna().sum()
# Out:
# date_         0
# close_btc     5
# close_eth     0
# high_btc      0
# high_eth      0
# low_btc       0
# low_eth       0
# open_btc      0
# open_eth      0
# volume_btc    0
# volume_eth    0
# dtype: int64

# %%
df = df.replace(0, np.nan)
df.isna().sum()
# Out:
# date_         0
# close_btc     5
# close_eth     0
# high_btc      0
# high_eth      0
# low_btc       0
# low_eth       0
# open_btc      0
# open_eth      0
# volume_btc    0
# volume_eth    3
# dtype: int64

# %%
df = df.interpolate()
df.head(6)
# Out:
#        date_    close_btc   close_eth     high_btc    high_eth      low_btc  \
# 0 2020-01-01  7200.174316  130.802002  7254.330566  132.835358  7174.944336
# 1 2020-01-02  7360.760661  127.410179  7212.155273  130.820038  6935.270020
# 2 2020-01-03  7521.347005  134.171707  7413.715332  134.554016  6914.996094
# 3 2020-01-04  7681.933350  135.069366  7427.385742  136.052719  7309.514160
# 4 2020-01-05  7842.519694  136.276779  7544.497070  139.410202  7400.535645
# 5 2020-01-06  8003.106038  144.304153  7781.867188  144.328186  7409.292969
#
#       low_eth     open_btc    open_eth   volume_btc    volume_eth
# 0  129.198288  7194.892090  129.630661  18565664997  7.935230e+09
# 1  126.954910  7202.551270  130.820038  20802083465  8.032709e+09
# 2  126.490021  6984.428711  127.411263  28111481032  8.297969e+09
# 3  133.040558  7345.375488  134.168518  18444271275  8.563228e+09
# 4  135.045624  7410.451660  135.072098  19725074095  8.828488e+09
# 5  136.079636  7410.452148  136.305542  23276261598  9.093747e+09

# %%
df.isna().sum()
# Out:
# date_         0
# close_btc     0
# close_eth     0
# high_btc      0
# high_eth      0
# low_btc       0
# low_eth       0
# open_btc      0
# open_eth      0
# volume_btc    0
# volume_eth    0
# dtype: int64

# %%
df.dtypes
# Out:
# date_         datetime64[ns]
# close_btc            float64
# close_eth            float64
# high_btc             float64
# high_eth             float64
# low_btc              float64
# low_eth              float64
# open_btc             float64
# open_eth             float64
# volume_btc             int64
# volume_eth           float64
# dtype: object

# %%
df = df.set_index('date_')
df.head()
# Out:
#               close_btc   close_eth     high_btc    high_eth      low_btc  \
# date_
# 2020-01-01  7200.174316  130.802002  7254.330566  132.835358  7174.944336
# 2020-01-02  7360.760661  127.410179  7212.155273  130.820038  6935.270020
# 2020-01-03  7521.347005  134.171707  7413.715332  134.554016  6914.996094
# 2020-01-04  7681.933350  135.069366  7427.385742  136.052719  7309.514160
# 2020-01-05  7842.519694  136.276779  7544.497070  139.410202  7400.535645
#
#                low_eth     open_btc    open_eth   volume_btc    volume_eth
# date_
# 2020-01-01  129.198288  7194.892090  129.630661  18565664997  7.935230e+09
# 2020-01-02  126.954910  7202.551270  130.820038  20802083465  8.032709e+09
# 2020-01-03  126.490021  6984.428711  127.411263  28111481032  8.297969e+09
# 2020-01-04  133.040558  7345.375488  134.168518  18444271275  8.563228e+09
# 2020-01-05  135.045624  7410.451660  135.072098  19725074095  8.828488e+09

# %%
df.describe()
# Out:
#            close_btc    close_eth       high_btc     high_eth        low_btc  \
# count    1947.000000  1947.000000    1947.000000  1947.000000    1947.000000
# mean    39728.820061  2009.630708   40544.550756  2062.790756   38788.037408
# std     24479.502559  1128.279039   24970.555360  1159.736336   23924.931646
# min      4970.788086   110.605873    5331.833984   116.021622    4106.980957
# 25%     20283.235352  1294.604858   20730.510742  1332.943909   19869.300781
# 50%     35510.289062  1889.322388   36436.421875  1926.421753   34086.152344
# 75%     57378.750000  2906.588501   58522.062500  2971.952759   55752.888672
# max    106146.265625  4812.087402  109114.882812  4891.704590  105291.734375
#
#            low_eth       open_btc     open_eth    volume_btc    volume_eth
# count  1947.000000    1947.000000  1947.000000  1.947000e+03  1.947000e+03
# mean   1949.521298   39685.617860  2008.963560  3.372061e+10  1.700923e+10
# std    1094.321159   24461.815504  1129.411226  1.983551e+10  1.070540e+10
# min      95.184303    5002.578125   110.406784  5.331173e+09  2.081626e+09
# 25%    1261.469299   20252.384766  1294.421326  2.078402e+10  9.715886e+09
# 50%    1852.790894   35502.941406  1889.073730  3.020224e+10  1.487800e+10
# 75%    2795.339966   57362.798828  2906.467041  4.095025e+10  2.105247e+10
# max    4718.039062  106147.296875  4810.071289  3.509679e+11  9.245355e+10

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['volume_btc'], label='BTC Volume', color='blue')
plt.plot(df.index, df['volume_eth'], label='ETH Volume', color='orange')
plt.title('BTC and ETH Trading Volumes (2020 - 01) after interpolation')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.grid(True)

# Step 4: Save the plot to a file
plt.savefig('btc_eth_volumes_interpolated.png')

# Step 5: Display the plot
plt.show()

# Step 6: Close the figure to free memory
plt.close()

# %%
max_volume = df['volume_btc'].max()
max_volume
# Out:
# np.int64(350967941479)

# %%
max_volume_date = df.index[df['volume_btc'] == max_volume][0]
max_volume_date
# Out:
# Timestamp('2021-02-26 00:00:00')

# %%
# Use IQR to detect outliers in volume_btc
Q1 = df['volume_btc'].quantile(0.25)
Q3 = df['volume_btc'].quantile(.75)

IQR = Q3 - Q1

upper_bounds = Q3 + 1.5 * IQR
lower_bounds = Q1 - 1.5 * IQR

df_no_outliers = df[(df['volume_btc'] >= lower_bounds) & (df['volume_btc'] <= upper_bound)]
df_no_outliers.head()
# Out:
#               close_btc   close_eth     high_btc    high_eth      low_btc  \
# date_
# 2020-01-01  7200.174316  130.802002  7254.330566  132.835358  7174.944336
# 2020-01-02  7360.760661  127.410179  7212.155273  130.820038  6935.270020
# 2020-01-03  7521.347005  134.171707  7413.715332  134.554016  6914.996094
# 2020-01-04  7681.933350  135.069366  7427.385742  136.052719  7309.514160
# 2020-01-05  7842.519694  136.276779  7544.497070  139.410202  7400.535645
#
#                low_eth     open_btc    open_eth   volume_btc    volume_eth
# date_
# 2020-01-01  129.198288  7194.892090  129.630661  18565664997  7.935230e+09
# 2020-01-02  126.954910  7202.551270  130.820038  20802083465  8.032709e+09
# 2020-01-03  126.490021  6984.428711  127.411263  28111481032  8.297969e+09
# 2020-01-04  133.040558  7345.375488  134.168518  18444271275  8.563228e+09
# 2020-01-05  135.045624  7410.451660  135.072098  19725074095  8.828488e+09

# %%
# Step 5: Print summary
print("Original DataFrame shape:", df.shape)
print("DataFrame shape after removing outliers:", df_no_outliers.shape)
print("\nOutliers removed (if any):")
outliers = df[(df['volume_btc'] < lower_bound) | (df['volume_btc'] > upper_bound)]
if not outliers.empty:
    for date, row in outliers.iterrows():
        print(f"Date: {date}, Volume: {row['volume_btc']}")
else:
    print("No outliers detected.")

# %%
# Step 6: Visualize original and cleaned data
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['volume_btc'], label='Original BTC Volume', color='blue', alpha=0.5)
plt.plot(df_no_outliers.index, df_no_outliers['volume_btc'], label='BTC Volume (No Outliers)', color='green')
plt.plot(df.index, df['volume_eth'], label='ETH Volume', color='orange', alpha=0.5)
if not outliers.empty:
    plt.scatter(outliers.index, outliers['volume_btc'], color='red', label='Outliers', zorder=5)
plt.title('BTC and ETH Trading Volumes (2020-01) with Outlier Analysis')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.grid(True)
plt.savefig('btc_eth_volumes_outlier_analysis.png')
plt.show()
plt.close()

# %%
df_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1857 entries, 2020-01-01 to 2025-04-30
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   close_btc   1857 non-null   float64
#  1   close_eth   1857 non-null   float64
#  2   high_btc    1857 non-null   float64
#  3   high_eth    1857 non-null   float64
#  4   low_btc     1857 non-null   float64
#  5   low_eth     1857 non-null   float64
#  6   open_btc    1857 non-null   float64
#  7   open_eth    1857 non-null   float64
#  8   volume_btc  1857 non-null   int64
#  9   volume_eth  1857 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 159.6 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1947 entries, 2020-01-01 to 2025-04-30
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   close_btc   1947 non-null   float64
#  1   close_eth   1947 non-null   float64
#  2   high_btc    1947 non-null   float64
#  3   high_eth    1947 non-null   float64
#  4   low_btc     1947 non-null   float64
#  5   low_eth     1947 non-null   float64
#  6   open_btc    1947 non-null   float64
#  7   open_eth    1947 non-null   float64
#  8   volume_btc  1947 non-null   int64
#  9   volume_eth  1947 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 231.9 KB
